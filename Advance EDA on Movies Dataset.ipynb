# %% [markdown]
# # <p style="background: linear-gradient(to right, #4B0082, #8A2BE2); font-size: 25px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif;"> ⊚⃝⸜✩Explanatory Data Analysis (Movies Dataset) ⊚⃝⸜✩</p>

# %% [markdown]
# # <center><p style="background: linear-gradient(to right, #8B4513, #A0522D); font-size: 20px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #D2691E; width:70%">☕︎ [̲̅$̲̅(̲̅ ͡°Notebook-Structure°̲̅)̲̅$̲̅] ☕︎ </p></center>
#
#
# <p style="background: linear-gradient(to right, #4B0082, #8A2BE2); font-size: 18px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #FF1493; width:45%; border-top-right-radius: 70px;">
#   The best and the worst movies...
# </p>
#
# 2. __Filter__ the Dataset and __find the best/worst n Movies__ with the
# - Highest Revenue
# - Highest Budget
# - Highest Profit (=Revenue - Budget)
# - Lowest Profit (=Revenue - Budget)
# - Highest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Lowest Return on Investment (=Revenue / Budget) (only movies with Budget >= 10)
# - Highest number of Votes
# - Highest Rating (only movies with 10 or more Ratings)
# - Lowest Rating (only movies with 10 or more Ratings)
# - Highest Popularity
#
#
# <p style="background: linear-gradient(to right, #4B0082, #8A2BE2); font-size: 18px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #FF1493; width:45%; border-top-right-radius: 70px;"> Find your next Movie </p>
#
# 3. __Filter__ the Dataset for movies that meet the following conditions:<br>
# __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__<br>
# __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__<br>
# __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__<br>
# __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__<br>
#
#
# <p style="background: linear-gradient(to right, #4B0082, #8A2BE2); font-size: 18px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #FF1493; width:45%; border-top-right-radius: 70px;"> Are Franchises more successful?
# </p>
#
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating
#
# <p style="background: linear-gradient(to right, #4B0082, #8A2BE2); font-size: 18px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #FF1493; width:45%; border-top-right-radius: 70px;">
#  Most Successful Franchises:
# </p>
#
# 5. __Find__ the __most successful Franchises__ in terms of
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__
#
# <p style="background: linear-gradient(to right, #4B0082, #8A2BE2); font-size: 18px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #FF1493; width:45%; border-top-right-radius: 70px;">
#   Most Successful Directors
# </p>
#
# 6. __Find__ the __most successful Directors__ in terms of
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %% [markdown]
# ## <center><p style="background: linear-gradient(to right, #008080, #20B2AA); font-size: 25px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; width:70%;">☕︎ [̲̅$̲̅(̲̅ ͡°Let's-Dive-In°̲̅)̲̅$̲̅] ☕︎</p></center>
#
# # <p style="background: linear-gradient(to right, #8B4513, #A0522D); font-size: 25px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #D2691E; border-top-left-radius: 30px; border-bottom-right-radius: 30px;"> Import Libraries </p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from wordcloud import WordCloud

pd.options.display.max_columns = 30
pd.options.display.float_format = '{:.2f}'.format

from IPython.display import HTML

# %% [markdown]
# <div style="background-color: #A67B5B; border-radius: 10px; padding: 20px; text-align: center; font-family: 'Trebuchet MS', sans-serif; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);">
#   <p style="font-size: 25px; color: #FFBF00;">🟡Please <span style="color: #003285;">upvote</span> the kernel if you like my analysis🥰🥰🤞🤞🤞</p>
# </div>

# %% [markdown]
# ## `Data Import and first Inspection`

# %% [markdown]
# 1. __Import__ the movies dataset from the CSV file "movies_complete.csv". __Inspect__ the data.

# %%
df = pd.read_csv("/kaggle/input/imdb-file/movies_complete.csv", parse_dates= ['release_date'])
df.head(2)
# Out:
#      id      title                                    tagline release_date  \
# 0   862  Toy Story                                        NaN   1995-10-30
# 1  8844    Jumanji  Roll the dice and unleash the excitement!   1995-12-15
#
#                      genres belongs_to_collection original_language  \
# 0   Animation|Comedy|Family  Toy Story Collection                en
# 1  Adventure|Fantasy|Family                   NaN                en
#
#    budget_musd  revenue_musd  \
# 0        30.00        373.55
# 1        65.00        262.80
#
#                                 production_companies  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures|Teitler Film|Interscope Commu...
#
#        production_countries  vote_count  vote_average  popularity  runtime  \
# 0  United States of America     5415.00          7.70       21.95    81.00
# 1  United States of America     2413.00          6.90       17.02   104.00
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  datetime64[ns]
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %% [markdown]
# * Dataset has 44691 entries and 22 columns.
# * There is some null values in some columns.

# %% [markdown]
# # <p style="background: linear-gradient(to right, #8B4513, #A0522D); font-size: 25px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #D2691E; border-top-left-radius: 30px; border-bottom-right-radius: 30px;"> Some additional information on Dataset Features/Columns </p>

# %% [markdown]
# * **id:** The ID of the movie (clear/unique identifier).
# * **title:** The Official Title of the movie.
# * **tagline:** The tagline of the movie.
# * **release_date:** Theatrical Release Date of the movie.
# * **genres:** Genres associated with the movie.
# * **belongs_to_collection:** Gives information on the movie series/franchise the particular film belongs to.
# * **original_language:** The language in which the movie was originally shot in.
# * **budget_musd:** The budget of the movie in million dollars.
# * **revenue_musd:** The total revenue of the movie in million dollars.
# * **production_companies:** Production companies involved with the making of the movie.
# * **production_countries:** Countries where the movie was shot/produced in.
# * **vote_count:** The number of votes by users, as counted by TMDB.
# * **vote_average:** The average rating of the movie.
# * **popularity:** The Popularity Score assigned by TMDB.
# * **runtime:** The runtime of the movie in minutes.
# * **overview:** A brief blurb of the movie.
# * **spoken_languages:** Spoken languages in the film.
# * **poster_path:** The URL of the poster image.
# * **cast:** (Main) Actors appearing in the movie.
# * **cast_size:** number of Actors appearing in the movie.
# * **director:** Director of the movie.
# * **crew_size:** Size of the film crew (incl. director, excl. actors).

# %%
df.genres[1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
df.cast[0]
# Out:
# 'Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette'

# %%
df.describe()
# Out:
#              id                   release_date  budget_musd  revenue_musd  \
# count  44691.00                          44657      8854.00       7385.00
# mean  107186.24  1992-04-28 16:30:02.539355520        21.67         68.97
# min        2.00            1874-12-09 00:00:00         0.00          0.00
# 25%    26033.50            1978-08-12 00:00:00         2.00          2.41
# 50%    59110.00            2001-08-16 00:00:00         8.20         16.87
# 75%   154251.00            2010-12-10 00:00:00        25.00         67.64
# max   469172.00            2017-12-27 00:00:00       380.00       2787.97
# std   111806.36                            NaN        34.36        146.61
#
#        vote_count  vote_average  popularity  runtime  cast_size  crew_size
# count    44691.00      42077.00    44691.00 43179.00   44691.00   44691.00
# mean       111.65          6.00        2.96    97.57      12.48      10.31
# min          0.00          0.00        0.00     1.00       0.00       0.00
# ...

# %% [markdown]
# ### Frequancy Distribution

# %%
df.hist(figsize= (20,12), bins =100)
plt.show()

# %%
df.budget_musd.value_counts(dropna=False).head(20)
# Out:
# budget_musd
# NaN      35837
# 5.00       286
# 10.00      258
# 20.00      243
# 2.00       241
# 15.00      226
# 3.00       220
# 25.00      206
# 1.00       195
# 30.00      189
# 4.00       180
# 6.00       173
# 12.00      171
# 40.00      166
# 8.00       155
# 35.00      141
# 0.50       141
# 7.00       137
# 50.00      124
# 1.50       119
# Name: count, dtype: int64

# %%
df['revenue_musd'].value_counts(dropna=False).head(20)
# Out:
# revenue_musd
# NaN      37306
# 12.00       20
# 11.00       19
# 10.00       19
# 2.00        18
# 6.00        17
# 5.00        14
# 0.50        13
# 8.00        13
# 0.00        12
# 14.00       12
# 7.00        11
# 3.00        10
# 20.00       10
# 1.00        10
# 4.00         9
# 1.50         9
# 0.00         9
# 30.00        8
# 16.00        8
# Name: count, dtype: int64

# %%
df['vote_average'].value_counts(dropna=False).head(20)
# Out:
# vote_average
# NaN     2614
# 6.00    2421
# 5.00    1969
# 7.00    1859
# 6.50    1705
# 6.30    1583
# 5.50    1369
# 5.80    1358
# 6.40    1343
# 6.70    1328
# 6.80    1316
# 6.10    1274
# 6.60    1250
# 6.20    1240
# 5.90    1189
# 5.30    1068
# 5.70    1039
# 6.90    1029
# 5.60     994
# 7.30     987
# Name: count, dtype: int64

# %%
df['vote_count'].value_counts()
# Out:
# vote_count
# 1.00       3186
# 2.00       3056
# 3.00       2729
# 0.00       2614
# 4.00       2442
#            ...
# 4956.00       1
# 1638.00       1
# 4436.00       1
# 3833.00       1
# 827.00        1
# Name: count, Length: 1820, dtype: int64

# %%
df.describe(include='object')
# Out:
#              title                 tagline genres belongs_to_collection  \
# count        44691                   20284  42586                  4463
# unique       41605                   20171   4044                  1691
# top     Cinderella  Based on a true story.  Drama       The Bowery Boys
# freq            11                       7   4935                    29
#
#        original_language       production_companies      production_countries  \
# count              44681                      33356                     38835
# unique                89                      22537                      2377
# top                   en  Metro-Goldwyn-Mayer (MGM)  United States of America
# freq               31755                        741                     17723
#
#                                     overview spoken_languages  \
# count                                  43740            41094
# unique                                 43715             1828
# ...

# %%
df[df.title == 'Cinderella']
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
# 44633   98604  Cinderella                                 NaN   2012-02-14
#
# ...

# %% [markdown]
# # <p style="background: linear-gradient(to right, #8B4513, #A0522D); font-size: 25px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #D2691E; border-top-left-radius: 30px; border-bottom-right-radius: 30px;">The best and the worst movies... </p>

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %% [markdown]
# ### Creating a Required features Dataset:

# %%
df_best = df[['poster_path', 'title', 'budget_musd', 'revenue_musd',
             'vote_count', 'vote_average', 'popularity']].copy()

df_best.head(2)
# Out:
#                                          poster_path      title  budget_musd  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...  Toy Story        30.00
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...    Jumanji        65.00
#
#    revenue_musd  vote_count  vote_average  popularity
# 0        373.55     5415.00          7.70       21.95
# 1        262.80     2413.00          6.90       17.02

# %%
df_best["profit_musd"] = df.revenue_musd.sub(df.budget_musd)
df_best["return"] = df.revenue_musd.div(df.budget_musd)

# %%
df_best.head(3)
# Out:
#                                          poster_path             title  \
# 0  <img src='http://image.tmdb.org/t/p/w185//uXDf...         Toy Story
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...           Jumanji
# 2  <img src='http://image.tmdb.org/t/p/w185//1FSX...  Grumpier Old Men
#
#    budget_musd  revenue_musd  vote_count  vote_average  popularity  \
# 0        30.00        373.55     5415.00          7.70       21.95
# 1        65.00        262.80     2413.00          6.90       17.02
# 2          NaN           NaN       92.00          6.50       11.71
#
#    profit_musd  return
# 0       343.55   12.45
# 1       197.80    4.04
# 2          NaN     NaN

# %% [markdown]
# ## Renaming Columns

# %%
df_best.columns = ["", "Title", "Budget", "Revenue", "Votes", "Average Rating", "Popularity", "Profit", "ROI"]

# %%
df_best.set_index('Title', inplace=True)

# %%
df_best.head(6)
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
# Heat                         <img src='http://image.tmdb.org/t/p/w185//lbf2...
#
#                              Budget  Revenue   Votes  Average Rating  \
# Title
# Toy Story                     30.00   373.55 5415.00            7.70
# Jumanji                       65.00   262.80 2413.00            6.90
# Grumpier Old Men                NaN      NaN   92.00            6.50
# Waiting to Exhale             16.00    81.45   34.00            6.10
# ...

# %%
df_best.iloc[0,0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>"

# %% [markdown]
# ### Creating subset of dataset for Movie Posters

# %%
subset = df_best.iloc[:5, :2]

# %%
subset.to_html(escape=False)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th></th>\n      <th>Budget</th>\n    </tr>\n    <tr>\n      <th>Title</th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Toy Story</th>\n      <td><img src=\'http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg\' style=\'height:100px;\'></td>\n      <td>30.00</td>\n    </tr>\n    <tr>\n      <th>Jumanji</th>\n      <td><img src=\'http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg\' style=\'height:100px;\'></td>\n      <td>65.00</td>\n    </tr>\n    <tr>\n      <th>Grumpier Old Men</th>\n      <td><img src=\'http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg\' style=\'height:100px;\'></td>\n      <td>NaN</td>\n    </tr>\n    <tr>\n      <th>Waiting to Exhale</th>\n      <td><img src=\'http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg\' style=\'height:100px;\'></td>\n      <td>16.00</
# ...

# %% [markdown]
# #### Convert into HTML page

# %%
HTML(subset.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.00</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %% [markdown]
# ### Making a function

# %%
def best_worst(n, by, ascending = False, min_bud = 0, min_votes = 0):
    
    
    df2 = df_best.loc[(df_best.Budget >= min_bud) & (df_best.Votes >= min_votes), 
                      ["", by]].sort_values(by = by, ascending = ascending).head(n).copy()
    
    return HTML(df2.to_html(escape=False))

# %% [markdown]
# __Movies Top 5 - Highest Revenue__

# %%
best_worst(n=5, by='Revenue')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2787.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>2068.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1845.03</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Budget__

# %%
best_worst(n=5, by='Budget')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Budget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Profit__

# %%
best_worst(n=5, by='Profit')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Profit</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>1823.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.03</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Profit__

# %%
best_worst(5, 'Revenue', ascending=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Merry Widow</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//hOVFpaZolrAVWdQ4r3mGxOadhkX.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>The Wind in the Willows</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//nsOM52BsDeHzc0yI27bah2OWems.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>The Letters</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8qnZycQWka7I8TbZ7UcvJ6I3weB.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Mute Witness</th>
# ...

# %% [markdown]
# __Movies Top 5 - Highest ROI__

# %%
best_worst(5, 'ROI', min_bud=50 )
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>15.63</td>
#     </tr>
#     <tr>
#       <th>Jurassic Park</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oU7Oq2kFAAlGqbU4VoAE36g4hoI.jpg' style='height:100px;'></td>
#       <td>14.60</td>
#     </tr>
#     <tr>
#       <th>The Twilight Saga: New Moon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//j5jM5pq78ObAXX1WhTsb115EkLl.jpg' style='height:100px;'></td>
#       <td>14.20</td>
#     </tr>
#     <tr>
#       <th>Deadpool</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest ROI__

# %%
best_worst(5, "ROI", ascending=True, min_bud=100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Adventures of Pluto Nash</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//96vvhLWWDosS1zRrfQ6XEGAzByL.jpg' style='height:100px;'></td>
#       <td>0.07</td>
#     </tr>
#     <tr>
#       <th>The Alamo</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//aZrWYkxCCwSPKp4VjVvn46uHbIX.jpg' style='height:100px;'></td>
#       <td>0.18</td>
#     </tr>
#     <tr>
#       <th>Live by Night</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//bkd46T4RplawnDjpHoI8mhzTLks.jpg' style='height:100px;'></td>
#       <td>0.21</td>
#     </tr>
#     <tr>
#       <th>Mars Needs Moms</th>
# ...

# %% [markdown]
# __Movies Top 5 - Most Votes__

# %%
best_worst(5, 'Votes')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Votes</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Inception</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9gk7adHYeDvHkCSEqAvQNLV5Uge.jpg' style='height:100px;'></td>
#       <td>14075.00</td>
#     </tr>
#     <tr>
#       <th>The Dark Knight</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qJ2tW6WMUDux911r6m7haRef0WH.jpg' style='height:100px;'></td>
#       <td>12269.00</td>
#     </tr>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>12114.00</td>
#     </tr>
#     <tr>
#       <th>The Avengers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//RYMX2wcKCBAr24UyPD7xwmjaTn.jpg' style='height:100px;'></td>
# ...

# %% [markdown]
# __Movies Top 5 - Highest Rating__

# %%
best_worst(5, 'Average Rating', min_votes=50)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Dilwale Dulhania Le Jayenge</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2CAL2433ZeIihfX1Hb2139CX0pW.jpg' style='height:100px;'></td>
#       <td>9.10</td>
#     </tr>
#     <tr>
#       <th>Human</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vdZgH8cr73DJTLwvyzFpmm9l3xV.jpg' style='height:100px;'></td>
#       <td>8.60</td>
#     </tr>
#     <tr>
#       <th>The Godfather</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//iVZ3JAcAjmguGPnRNfWFOtLHOuY.jpg' style='height:100px;'></td>
#       <td>8.50</td>
#     </tr>
#     <tr>
#       <th>The Shawshank Redemption</th>
# ...

# %% [markdown]
# __Movies Top 5 - Lowest Rating__

# %%
best_worst(5, 'Average Rating', ascending=True, min_votes=100)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>House of the Dead</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5jBIUM0tqq8QwNbY8w1RZdU6uWz.jpg' style='height:100px;'></td>
#       <td>2.80</td>
#     </tr>
#     <tr>
#       <th>Dragonball Evolution</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//23PcKOqNdhKeMFzORzQGn5eC44N.jpg' style='height:100px;'></td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Battlefield Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wXCRuBHdJ5aTFQdsuGJFXNdo79T.jpg' style='height:100px;'></td>
#       <td>3.00</td>
#     </tr>
#     <tr>
#       <th>Disaster Movie</th>
# ...

# %%
best_worst(5, "Average Rating", ascending = True, min_votes = 20, min_bud = 20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Foodfight!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//R1zn75Yz4wpdd85byqhP7mT6No.jpg' style='height:100px;'></td>
#       <td>2.30</td>
#     </tr>
#     <tr>
#       <th>Dragonball Evolution</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//23PcKOqNdhKeMFzORzQGn5eC44N.jpg' style='height:100px;'></td>
#       <td>2.90</td>
#     </tr>
#     <tr>
#       <th>Battlefield Earth</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//wXCRuBHdJ5aTFQdsuGJFXNdo79T.jpg' style='height:100px;'></td>
#       <td>3.00</td>
#     </tr>
#     <tr>
#       <th>Far Cry</th>
# ...

# %% [markdown]
# __Movies Top 5 - Most Popular__

# %%
best_worst(5, "Popularity")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.49</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.34</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.25</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
# ...

# %% [markdown]
# # <p style="background: linear-gradient(to right, #8B4513, #A0522D); font-size: 25px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #D2691E; border-top-left-radius: 30px; border-bottom-right-radius: 30px;"> Find your next Movie </p>

# %% [markdown]
# ### __Search 1: Science Fiction Action Movie with Bruce Willis (sorted from high to low Rating)__

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %% [markdown]
# #### First filter the require genres:

# %%
mask_genre = df.genres.str.contains('Action') & df.genres.str.contains('Science Fiction')

# %% [markdown]
# #### Filter the Require Actor:

# %%
actor = df.cast.str.contains('Bruce Willis')

# %% [markdown]
# #### Now implementing these two varaibles to acheive the task:

# %%
bruce = df.loc[mask_genre & actor, ["title", "poster_path", "vote_average"]].sort_values(by='vote_average', ascending=False).set_index('title')

# %%
HTML(bruce.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>The Fifth Element</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>Looper</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>Armageddon</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>Surrogates</th>
# ...

# %% [markdown]
# ### __Search 2: Movies with Uma Thurman and directed by Quentin Tarantino (sorted from short to long runtime)__

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %% [markdown]
# #### Filter the actress from the dataset:

# %%
actress = df.cast.str.contains('Uma Thurman')

# %% [markdown]
# #### Filter the director from the dataset:

# %%
director = df.director.str.contains('Quentin Tarantino')

# %% [markdown]
# #### search the require task using these variables:

# %%
search = df.loc[actress & director, ['title', 'poster_path', 'runtime']].sort_values(by='runtime', ascending=True).set_index('title')

# %%
HTML(search.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kill Bill: Vol. 1</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>111.00</td>
#     </tr>
#     <tr>
#       <th>Kill Bill: Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>136.00</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>154.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### __Search 3: Most Successful Pixar Studio Movies between 2010 and 2015 (sorted from high to low Revenue)__

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %%
df.production_companies
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures|Teitler Film|Interscope Commu...
# 2                              Warner Bros.|Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4                Sandollar Productions|Touchstone Pictures
#                                ...
# 44686                                                  NaN
# 44687                                          Sine Olivia
# 44688                              American World Pictures
# 44689                                            Yermoliev
# 44690                                                  NaN
# Name: production_companies, Length: 44691, dtype: object

# %% [markdown]
# #### Filtering pixar studio from production companies:

# %%
pixar = df.production_companies.str.contains('Pixar').fillna(False)
# Out:
# /tmp/ipykernel_24/586958794.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   pixar = df.production_companies.str.contains('Pixar').fillna(False)

# %%
df.release_date
# Out:
# 0       1995-10-30
# 1       1995-12-15
# 2       1995-12-22
# 3       1995-12-22
# 4       1995-02-10
#            ...
# 44686          NaT
# 44687   2011-11-17
# 44688   2003-08-01
# 44689   1917-10-21
# 44690   2017-06-09
# Name: release_date, Length: 44691, dtype: datetime64[ns]

# %% [markdown]
# #### Filtering Release date between 2010 and 2015:

# %%
date = df.release_date.between("2010-01-01", "2015-01-01")

# %% [markdown]
# #### Filtering Required solution using these variables:

# %%
pixar = df.loc[pixar & date, ["title", "poster_path", "production_companies","release_date"]].sort_values(by='release_date', ascending=True).set_index("title")

# %%
HTML(pixar.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>production_companies</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story 3</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>Walt Disney Pictures|Pixar Animation Studios</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>Day & Night</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//eQ1QUZfblOrusXVfbzzCuUaM7ix.jpg' style='height:100px;'></td>
#       <td>Walt Disney Pictures|Pixar Animation Studios</td>
#       <td>2010-06-17</td>
#     </tr>
#     <tr>
#       <th>La luna</th>
# ...

# %% [markdown]
# ### __Search 4: Action or Thriller Movie with original language English and minimum Rating of 7.5 (most recent movies first)__

# %% [markdown]
# #### FIltering Required Genres:

# %%
mask_genre = df.genres.str.contains('Action') | df.genres.str.contains('Thriller')

# %% [markdown]
# #### Filtering Required languange:

# %%
lang = df.original_language == 'en'

# %% [markdown]
# #### Filtering Require Rating:

# %%
rating= df.vote_average >=7.5

# %% [markdown]
# #### Filtering Voting count:

# %%
mask_vote_co = df.vote_count >= 10

# %% [markdown]
# #### Performing the search using the filtered variables:

# %%
search1 = df.loc[mask_genre & lang & rating, ["title", "poster_path", "genres", "vote_average", "vote_count", "release_date"]].sort_values(by='release_date', ascending=False).set_index('title')

# %% [markdown]
# #### Converting to HTML page to view better:

# %%
HTML(search1.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>genres</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Descendants 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//8BNyZlBk4Hs92z6UrvFDjvx3yMb.jpg' style='height:100px;'></td>
#       <td>TV Movie|Family|Action|Comedy|Music|Adventure</td>
#       <td>7.50</td>
#       <td>171.00</td>
#       <td>2017-07-21</td>
#     </tr>
#     <tr>
#       <th>Dunkirk</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//ebSnODDg9lbsMIaWg2uAbjn7TO5.jpg' style='height:100px;'></td>
#       <td>Action|Drama|History|Thriller|War</td>
#       <td>7.50</td>
#       <td>2712.00</td>
# ...

# %% [markdown]
# # <p style="background: linear-gradient(to right, #8B4513, #A0522D); font-size: 25px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #D2691E; border-top-left-radius: 30px; border-bottom-right-radius: 30px;"> What are the most common Words in Movie Titles and Taglines?</p>

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
df['tagline'][1]
# Out:
# 'Roll the dice and unleash the excitement!'

# %%
df.overview[1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
df.tagline.isnull().sum()
# Out:
# 24407

# %%
df.title.isnull().sum()
# Out:
# 0

# %%
df.overview.isnull().sum()
# Out:
# 951

# %% [markdown]
# #### Droping these Null values in columns:

# %%
title = df.title.dropna()
overview = df.overview.dropna()
tagline = df.tagline.dropna()

# %%
title
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 44686                         Subdue
# 44687            Century of Birthing
# 44688                       Betrayal
# 44689               Satan Triumphant
# 44690                       Queerama
# Name: title, Length: 44691, dtype: object

# %%
title_corpus = ' '.join(title)
overview_corpus = ' '.join(overview)
tagline_corpus = ' '.join(tagline)

# %% [markdown]
# ### WordCloud for Title

# %%
title_wordcloud = WordCloud(background_color='black', height=2000, width=4000, max_words= 200).generate(title_corpus)
title_wordcloud

# %%
plt.figure(figsize=(16,8))
plt.imshow(title_wordcloud, interpolation ="bilinear")
plt.axis('off')
plt.show()

# %% [markdown]
# ### WordCloud for Overview

# %%
overview_wordcloud = WordCloud(background_color = 'Black', height=2000, width = 4000, max_words= 200).generate(overview_corpus)
overview_wordcloud

plt.figure(figsize=(16,8))
plt.imshow(overview_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Word Cloud for TagLine

# %%
tagline_wordcloud= WordCloud(background_color='black', height=2000, width=4000).generate(tagline_corpus)

plt.figure(figsize=(16,8))
plt.imshow(tagline_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# # <p style="background: linear-gradient(to right, #8B4513, #A0522D); font-size: 25px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #D2691E; border-top-left-radius: 30px; border-bottom-right-radius: 30px;"> Are Franchises more successful? </p>

# %% [markdown]
# 4. __Analyze__ the Dataset and __find out whether Franchises (Movies that belong to a collection) are more successful than stand-alone movies__ in terms of:

# %% [markdown]
# - mean revenue
# - median Return on Investment
# - mean budget raised
# - mean popularity
# - mean rating

# %% [markdown]
# hint: use groupby()

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %%
df.belongs_to_collection.notna()
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: belongs_to_collection, Length: 44691, dtype: bool

# %%
df['Franchise'] = df.belongs_to_collection.notna()

# %%
df.head(2)
# Out:
#      id      title                                    tagline release_date  \
# 0   862  Toy Story                                        NaN   1995-10-30
# 1  8844    Jumanji  Roll the dice and unleash the excitement!   1995-12-15
#
#                      genres belongs_to_collection original_language  \
# 0   Animation|Comedy|Family  Toy Story Collection                en
# 1  Adventure|Fantasy|Family                   NaN                en
#
#    budget_musd  revenue_musd  \
# 0        30.00        373.55
# 1        65.00        262.80
#
#                                 production_companies  \
# 0                            Pixar Animation Studios
# 1  TriStar Pictures|Teitler Film|Interscope Commu...
#
#        production_countries  vote_count  vote_average  popularity  runtime  \
# 0  United States of America     5415.00          7.70       21.95    81.00
# 1  United States of America     2413.00          6.90       17.02   104.00
#
# ...

# %%
df.Franchise.value_counts()
# Out:
# Franchise
# False    40228
# True      4463
# Name: count, dtype: int64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Revenue__

# %%
df.groupby('Franchise').revenue_musd.mean()
# Out:
# Franchise
# False    44.74
# True    165.71
# Name: revenue_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Return on Investment / Profitability (median)__

# %%
df['ROI'] = df.revenue_musd.div(df.budget_musd)
df.groupby('Franchise').ROI.median()
# Out:
# Franchise
# False   1.62
# True    3.71
# Name: ROI, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Budget__

# %%
df.groupby('Franchise').budget_musd.mean()
# Out:
# Franchise
# False   18.05
# True    38.32
# Name: budget_musd, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Popularity__

# %%
df.groupby('Franchise').popularity.mean()
# Out:
# Franchise
# False   2.59
# True    6.25
# Name: popularity, dtype: float64

# %% [markdown]
# __Franchise vs. Stand-alone: Average Rating__

# %%
df.groupby('Franchise').vote_average.mean()
# Out:
# Franchise
# False   6.01
# True    5.96
# Name: vote_average, dtype: float64

# %%
df.groupby("Franchise").agg({"budget_musd": "mean", "revenue_musd": "mean", "vote_average": "mean",
                            "popularity": "mean", "ROI":"median", "vote_count":"mean"})
# Out:
#            budget_musd  revenue_musd  vote_average  popularity  ROI  \
# Franchise
# False            18.05         44.74          6.01        2.59 1.62
# True             38.32        165.71          5.96        6.25 3.71
#
#            vote_count
# Franchise
# False           78.29
# True           412.39

# %% [markdown]
# # <p style="background: linear-gradient(to right, #8B4513, #A0522D); font-size: 25px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #D2691E; border-top-left-radius: 30px; border-bottom-right-radius: 30px;"> Most Successful Franchises </p>

# %% [markdown]
# 5. __Find__ the __most successful Franchises__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total & mean budget__
# - __total & mean revenue__
# - __mean rating__

# %%
df.belongs_to_collection
# Out:
# 0                  Toy Story Collection
# 1                                   NaN
# 2             Grumpy Old Men Collection
# 3                                   NaN
# 4        Father of the Bride Collection
#                       ...
# 44686                               NaN
# 44687                               NaN
# 44688                               NaN
# 44689                               NaN
# 44690                               NaN
# Name: belongs_to_collection, Length: 44691, dtype: object

# %%
df.belongs_to_collection.value_counts()
# Out:
# belongs_to_collection
# The Bowery Boys                  29
# Totò Collection                  27
# James Bond Collection            26
# Zatôichi: The Blind Swordsman    26
# The Carry On Collection          25
#                                  ..
# Параграф 78 - Дилогия             1
# La Tour Infernale                 1
# Macskafogó gyűjtemény             1
# Сказки Чуковского                 1
# Adventures of a ...               1
# Name: count, Length: 1691, dtype: int64

# %%
franchises = df.groupby("belongs_to_collection").agg({"title":"count", "budget_musd": ["sum", "mean"], 
                                                      "revenue_musd": ["sum", "mean"],
                                                      "vote_average": "mean", "popularity": "mean",
                                                      "ROI":"median", 
                                                      "vote_count":"mean"})

# %%
franchises
# Out:
#                                      title budget_musd       revenue_musd  \
#                                      count         sum  mean          sum
# belongs_to_collection
# ... Has Fallen Collection                2      130.00 65.00       366.78
# 00 Schneider Filmreihe                   1        0.00   NaN         0.00
# 08/15 Collection                         1        0.00   NaN         0.00
# 100 Girls Collection                     2        0.00   NaN         0.00
# 101 Dalmatians (Animated) Collection     2        4.00  4.00       215.88
# ...                                    ...         ...   ...          ...
# Сказки Чуковского                        1        0.00   NaN         0.00
# Чебурашка и крокодил Гена                1        0.00   NaN         0.00
# Что Творят мужчины! (Коллекция)          2        2.00  2.00         0.00
# 男はつらいよ シリーズ                              3        0.00   NaN         0.00
# ...

# %%
franchises.nlargest(20, ("title", "count"))
# Out:
#                                        title budget_musd       revenue_musd  \
#                                        count         sum  mean          sum
# belongs_to_collection
# The Bowery Boys                           29        0.00   NaN         0.00
# Totò Collection                           27        0.00   NaN         0.00
# James Bond Collection                     26     1539.65 59.22      7106.97
# Zatôichi: The Blind Swordsman             26        0.00   NaN         0.00
# The Carry On Collection                   25        0.00   NaN         0.00
# Charlie Chan (Sidney Toler) Collection    21        0.00   NaN         0.00
# Pokémon Collection                        20      250.72 50.14       601.87
# Godzilla (Showa) Collection               16        2.81  0.56         0.00
# Charlie Chan (Warner Oland) Collection    15        0.00   NaN         0.00
# Dragon Ball Z (Movie) Collection          15        5.00  5.00       112.12
# ...

# %%
franchises.nlargest(20, ("revenue_musd", "mean"))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# Avatar Collection                       1      237.00 237.00      2787.97
# The Avengers Collection                 2      500.00 250.00      2924.96
# Frozen Collection                       2      150.00 150.00      1274.22
# Finding Nemo Collection                 2      294.00 147.00      1968.91
# The Hobbit Collection                   3      750.00 250.00      2935.52
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# Star Wars Collection                    8      854.35 106.79      7434.49
# Despicable Me Collection                6      299.00  74.75      3691.07
# Pirates of the Caribbean Collection     5     1250.00 250.00      4521.58
# ...

# %%
franchises.nlargest(20, ("budget_musd", "mean"))
# Out:
#                                         title budget_musd        revenue_musd  \
#                                         count         sum   mean          sum
# belongs_to_collection
# Tangled Collection                          2      260.00 260.00       591.79
# Pirates of the Caribbean Collection         5     1250.00 250.00      4521.58
# The Avengers Collection                     2      500.00 250.00      2924.96
# The Hobbit Collection                       3      750.00 250.00      2935.52
# Man of Steel Collection                     2      475.00 237.50      1536.11
# Avatar Collection                           1      237.00 237.00      2787.97
# The Amazing Spider-Man Collection           2      415.00 207.50      1457.93
# World War Z Collection                      1      200.00 200.00       531.87
# Spider-Man Collection                       3      597.00 199.00      2496.35
# The Dark Knight Collection                  3      585.00 195.00      2463.72
# ...

# %%
franchises[franchises[("vote_count", "mean")] >=1000].nlargest(20, ("vote_average", "mean"))
# Out:
#                                     title budget_musd        revenue_musd  \
#                                     count         sum   mean          sum
# belongs_to_collection
# The Lord of the Rings Collection        3      266.00  88.67      2916.54
# The Godfather Collection                3       73.00  24.33       429.38
# Blade Runner Collection                 1       28.00  28.00        33.14
# The Man With No Name Collection         3        2.00   0.67        35.50
# The Dark Knight Collection              3      585.00 195.00      2463.72
# Guardians of the Galaxy Collection      2      370.00 185.00      1636.74
# Kill Bill Collection                    2       60.00  30.00       333.11
# Kingsman Collection                     1       81.00  81.00       414.35
# How to Train Your Dragon Collection     2      310.00 155.00      1104.00
# Harry Potter Collection                 8     1280.00 160.00      7707.37
# ...

# %% [markdown]
# # <p style="background: linear-gradient(to right, #8B4513, #A0522D); font-size: 25px; color: white; text-align: center; padding: 12px; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); font-family: 'Trebuchet MS', sans-serif; border: 3px solid #D2691E; border-top-left-radius: 30px; border-bottom-right-radius: 30px;"> Most Successful Directors </p>

# %% [markdown]
# 6. __Find__ the __most successful Directors__ in terms of

# %% [markdown]
# - __total number of movies__
# - __total revenue__
# - __mean rating__

# %%
df.director.value_counts().head(20)
# Out:
# director
# John Ford             66
# Michael Curtiz        65
# Werner Herzog         54
# Alfred Hitchcock      53
# Woody Allen           49
# Georges Méliès        49
# Sidney Lumet          46
# Jean-Luc Godard       46
# Charlie Chaplin       44
# Raoul Walsh           43
# William A. Wellman    42
# Henry Hathaway        41
# Richard Thorpe        40
# Martin Scorsese       39
# Ingmar Bergman        39
# George Cukor          38
# Fritz Lang            38
# John Huston           38
# Mervyn LeRoy          37
# Robert Altman         37
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 8))
df.director.value_counts().head(20).sort_values().plot(kind='barh', color='#FF4500', alpha=0.7)
plt.title("Most Active Directors", fontsize=16, color='#FF4500', fontweight='bold')
plt.xlabel("Number of Movies", fontsize=12, color='#FF4500')
plt.ylabel("Director", fontsize=12, color='#FF4500')
plt.xticks(fontsize=10, color='#FF4500')
plt.yticks(fontsize=10, color='#FF4500')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_color('#FF4500')
plt.gca().spines['bottom'].set_color('#FF4500')
plt.show()

# %%
df.groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Steven Spielberg    9256.62
# Peter Jackson       6528.24
# Michael Bay         6437.47
# James Cameron       5900.61
# David Yates         5334.56
# Christopher Nolan   4747.41
# Robert Zemeckis     4138.23
# Tim Burton          4032.92
# Ridley Scott        3917.53
# Chris Columbus      3866.84
# Roland Emmerich     3798.40
# Ron Howard          3714.15
# J.J. Abrams         3579.22
# Gore Verbinski      3575.34
# George Lucas        3341.55
# Sam Raimi           3193.79
# Francis Lawrence    3183.34
# Clint Eastwood      3100.68
# Bill Condon         3017.30
# Joss Whedon         2963.83
# Name: revenue_musd, dtype: float64

# %%
plt.figure(figsize=(12, 8))
df.groupby("director").revenue_musd.sum().nlargest(20).sort_values().plot(kind='barh', color='#FF6347', alpha=0.7)
plt.title("Total Revenue by Director", fontsize=16, color='#FF4500', fontweight='bold')
plt.xlabel("Revenue (in MUSD)", fontsize=12, color='#FF4500')
plt.ylabel("Director", fontsize=12, color='#FF4500')
plt.xticks(fontsize=10, color='#FF4500')
plt.yticks(fontsize=10, color='#FF4500')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.gca().spines['left'].set_color('#FF4500')
plt.gca().spines['bottom'].set_color('#FF4500')
plt.show()

# %%
directors = df.groupby("director").agg({"title": "count", "vote_average" :"mean", "vote_count": "sum"})

# %%
directors
# Out:
#                      title  vote_average  vote_count
# director
#  Dale Trevillion\t       2          4.00        4.00
#  Davide Manuli           1          6.90       10.00
#  E.W. Swackhamer         1          5.90        5.00
#  Vitaliy Vorobyov        1          5.50        3.00
#  Yeon Sang-Ho            4          6.60     1039.00
# ...                    ...           ...         ...
# Ярополк Лапшин           1         10.00        1.00
# پیمان معادی              1          6.00        2.00
# 塩谷 直義                    1          7.20       40.00
# 杰森·莫玛                    1          5.80       28.00
# 진모영                      1          6.00        6.00
#
# [17349 rows x 3 columns]

# %%
directors[(directors.vote_count >= 10000) & (directors.title >= 10)].nlargest(20, "vote_average")
# Out:
#                    title  vote_average  vote_count
# director
# Hayao Miyazaki        14          7.70    14700.00
# Christopher Nolan     11          7.62    67344.00
# Quentin Tarantino     10          7.49    45910.00
# Wes Anderson          10          7.37    11743.00
# David Fincher         10          7.35    37588.00
# Martin Scorsese       39          7.22    35541.00
# Peter Jackson         13          7.14    47571.00
# Joel Coen             17          7.02    18139.00
# James Cameron         11          6.93    33736.00
# Stanley Kubrick       16          6.91    18214.00
# James Mangold         10          6.90    16607.00
# Steven Spielberg      33          6.89    62266.00
# Danny Boyle           14          6.87    16504.00
# Guy Ritchie           10          6.80    19626.00
# Robert Zemeckis       19          6.79    37666.00
# Terry Gilliam         14          6.76    10049.00
# Tim Burton            21          6.73    36922.00
# ...

# %%
df.genres = df.genres.astype(str)

# %%
df.loc[df.genres.str.contains("Horror")].groupby("director").revenue_musd.sum().nlargest(20)
# Out:
# director
# Paul W.S. Anderson    982.29
# James Wan             861.31
# Wes Craven            834.93
# Francis Lawrence      816.23
# Ridley Scott          689.00
# Marc Forster          531.87
# Steven Spielberg      500.10
# William Friedkin      466.40
# Darren Lynn Bousman   456.34
# M. Night Shyamalan    375.37
# Henry Joost           349.07
# David R. Ellis        348.74
# Adrian Lyne           346.11
# James DeMonaco        316.70
# Stephen Sommers       311.46
# Gore Verbinski        275.91
# Guillermo del Toro    261.63
# John R. Leonetti      255.27
# Fede Alvarez          254.64
# Jordan Peele          252.43
# Name: revenue_musd, dtype: float64

# %% [markdown]
# <div style="background: #2E8B57; padding: 20px; border-radius: 10px; text-align: center; font-family: 'Trebuchet MS', sans-serif; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2); color: white;">
#   <div style="font-size: 24px; margin-bottom: 10px;">Thank you for exploring my Notebook 📓</div>
#   <div style="font-size: 24px; margin-bottom: 20px;">Please upvote if you liked it 👍</div>
# </div>
